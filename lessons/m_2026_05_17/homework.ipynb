# %%
#Что такое list в python.
# list - это список различных значений, которые могут быть самых разных типов данных - от int до datetime или decimate.

# %%
''' Для чего нужны списки?
Списки позволяют хранить несколько значений в одной переменной и удобно работать с группами данных, выполняя различные операции -
- добавление, удаление и изменение элементов'''

# %%
#Порядок создания списка: ( есть несколько способов) 
#1. с помощью квадратных скобок
# Создание пустого списка:
empty_lyst = [] #пустой список
# например, можно создать строковый список
themes_of_python = [ 'while', 'for', 'if', 'def', 'list', 'LEGB...']

# %%
#2. с  помощью конструктора list()
# создание пустого списка:
empty_list = list()
chars = list('homework')
print(chars) # Выведет каждую букву слова, которое ввелось в скобках выше
# Out:
# ['h', 'o', 'm', 'e', 'w', 'o', 'r', 'k']

# %%
#3. с помощью вложенных списков:
# Например, списки списков
numbers = [[1, 10, 100], [2,20,200], [3,30,300]]
print(numbers)
# Out:
# [[1, 10, 100], [2, 20, 200], [3, 30, 300]]

# %%
#4 Добавление элементов в список
new_list = []

new_list.append(1)
new_list
# Out:
# [1]

# %%
new_list.append(5)
new_list
# Out:
# [1, 5]

# %%
list_for_append = [2,3]
new_list.extend(list_for_append)
new_list
# Out:
# [1, 5, 2, 3]

# %%
new_list.append(list_for_append)
new_list
# Out:
# [1, 5, 2, 3, [2, 3]]

# %%
new_list.insert(0, 10)
new_list
# Out:
# [10, 1, 5, 2, 3, [2, 3]]

# %%
new_list.insert(3, 4)
new_list
# Out:
# [10, 1, 5, 4, 2, 3, [2, 3]]

# %%
#4. чтение элементов списка (обращение к элементам)

# %%
new_list[5]
# Out:
# 3

# %%
new_list[6]
# Out:
# [2, 3]

# %%
new_list[-1]
# Out:
# [2, 3]

# %%
new_list
# Out:
# [10, 1, 5, 4, 2, 3, [2, 3]]

# %%
new_list[3:6]
# Out:
# [4, 2, 3]

# %%
new_list.insert(5, 4)
new_list
# Out:
# [10, 1, 5, 4, 2, 4, 3, [2, 3]]

# %%
new_list.index(4)
# Out:
# 3

# %%
#5. обновление элементов в списке
new_list = [1, 2, 3]
new_list
# Out:
# [1, 2, 3]

# %%
new_list[1] = 10
new_list
# Out:
# [1, 10, 3]

# %%
new_list[0:2] = [5, 6]
new_list
# Out:
# [5, 6, 3]

# %%
#4. удаление элементов списка
new_list = [1, 2, 3]
new_list
# Out:
# [1, 2, 3]

# %%
new_list.pop()
new_list
# Out:
# [1, 2]

# %%
new_list.pop(0)
new_list
# Out:
# [2]

# %%
new_list = [1, 2, 3, 4, 3]
new_list
# Out:
# [1, 2, 3, 4, 3]

# %%
new_list.remove(3)
new_list
# Out:
# [1, 2, 4, 3]

# %%
new_list.clear()
new_list
# Out:
# []

# %%
new_list = [1, 2, 3, 4, 3]
new_list
# Out:
# [1, 2, 3, 4, 3]

# %%
new_list = []
new_list
# Out:
# []
